# %% [markdown]
# <a href="https://colab.research.google.com/github/divyarayudu-10/Python---core/blob/main/Variables_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# variables.py
# This program demonstrates basic Python variables and data types

name = "Divya"          # stores the name
age = 22                # stores the age
is_student = True       # indicates student status
cgpa = 8.5              # academic score

print("Name:", name)
print("Age:", age)
print("Student:", is_student)
print("CGPA:", cgpa)
# Out:
# Name: Divya
# Age: 22
# Student: True
# CGPA: 8.5

# %%
print("My Name is Divya")
print( " I'm learning python")
# Out:
# My Name is Divya
#  I'm learning python
