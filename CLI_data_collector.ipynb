# %% [markdown]
# <a href="https://colab.research.google.com/github/divyarayudu-10/Python---core/blob/main/CLI_data_collector.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name=input("enter your name")
age=int(input("enter your age"))
city=input("enter your city")
salary=float(input("enter your salary"))
print("name",name)
print("age",age)
print("city",city)
print("salary",salary)
# Out:
# enter your namedivya
# enter your age23
# enter your cityrajahmundry
# enter your salary0
# name divya
# age 23
# city rajahmundry
# salary 0.0
